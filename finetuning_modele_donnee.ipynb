# %% [markdown]
# ## Fonctions necessaire

# %%
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    total_loss, correct, total = 0.0, 0, 0

    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * images.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total += images.size(0)

    return total_loss / total, correct / total

def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            total_loss += loss.item() * images.size(0)
            correct += (outputs.argmax(1) == labels).sum().item()
            total += images.size(0)

    return total_loss / total, correct / total

def train_model(model, train_loader, val_loader, num_epochs=20, save_dir="DenseNet121"):
    os.makedirs(save_dir, exist_ok=True)
    device_ = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device_)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    best_val_acc = 0.0
    best_model_wts = model.state_dict()
    log_file_path = os.path.join(save_dir, "training_log.txt")

    with open(log_file_path, "w") as log_file:
        for epoch in range(1, num_epochs + 1):
            train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device_)
            val_loss, val_acc = evaluate(model, val_loader, criterion, device_)

            log = (f"Epoch {epoch:02d} | TRAIN loss: {train_loss:.4f}, acc: {train_acc:.4f} | "
                   f"VALID loss: {val_loss:.4f}, acc: {val_acc:.4f} | LR: {optimizer.param_groups[0]['lr']:.2e}")
            print(log)
            all_losses_train.append(train_loss)
            all_losses_val.append(val_loss)
            all_acc_train.append(train_acc)
            all_acc_val.append(val_acc)

            log_file.write(log + "\n")

            scheduler.step(val_loss)

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_model_wts = model.state_dict()

    save_path = os.path.join(save_dir, f"best3_densenet121_acc{best_val_acc:.4f}.pth")
    torch.save(best_model_wts, save_path)
    print(f" Meilleur modèle sauvegardé : {save_path}")
    return model

# %% [markdown]
# # Ici on funetune sur notre nouveau jeu de données

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report
import os

# %%
data_dir = "dataset3"  # ton nouveau dossier

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_dir, transform=transform)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
class_names = dataset.classes
num_classes = len(class_names)

# %%
print(len(train_dataset))
# Out:
# 872

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Créer le modèle avec 4 classes (comme celui sauvegardé)
model = models.densenet121(pretrained=False)
model.classifier = nn.Linear(model.classifier.in_features, 5)
model.load_state_dict(torch.load("Dense5classes/best_densenet121_acc0.7600.pth"))
#model.load_state_dict(torch.load("DenseNet121/a/best_densenet121_acc0.7094.pth"))

model = model.to(device)
# Out:
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[24], line 6
#       2
#       3 # Créer le modèle avec 4 classes (comme celui sauvegardé)
#       4 model = models.densenet121(pretrained=False)
#       5 model.classifier = nn.Linear(model.classifier.in_features, 4)
# ----> 6 model.load_state_dict(torch.load("DenseNet121/a/best_densenet121_acc0.7094.pth"))
#       7 #model.load_state_dict(torch.load("DenseNet121/a/best_densenet121_acc0.7094.pth"))
#       8
#       9 model = model.to(device)
#
# File ~/env/lib/python3.12/site-packages/torch/serialization.py:1570, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1568 if weights_only:
#    1569     try:
# -> 1570         return _load(
#    1571             opened_zipfile,
#    1572             map_location,
#    1573             _weights_only_unpickler,
#    1574             overall_storage=overall_storage,
#    1575             **pickle_load_args,
#    1576         )
#    1577     except pickle.UnpicklingError as e:
#    1578         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#
# File ~/env/lib/python3.12/site-packages/torch/serialization.py:2190, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2188 global _serialization_tls
#    2189 _serialization_tls.map_location = map_location
# -> 2190 result = unpickler.load()
#    2191 _serialization_tls.map_location = None
#    2193 torch._utils._validate_loaded_sparse_tensors()
#
# File ~/env/lib/python3.12/site-packages/torch/_weights_only_unpickler.py:541, in Unpickler.load(self)
#     533     if (
#     534         type(pid) is tuple
#     535         and len(pid) > 0
#     536         and torch.serialization._maybe_decode_ascii(pid[0]) != "storage"
#     537     ):
#     538         raise UnpicklingError(
#     539             f"Only persistent_load of storage is allowed, but got {type(pid[0])}"
#     540         )
# --> 541     self.append(self.persistent_load(pid))
#     542 elif key[0] in [BINGET[0], LONG_BINGET[0]]:
#     543     idx = (read(1) if key[0] == BINGET[0] else unpack("<I", read(4)))[0]
#
# File ~/env/lib/python3.12/site-packages/torch/serialization.py:2154, in _load.<locals>.persistent_load(saved_id)
#    2152 else:
#    2153     nbytes = numel * torch._utils._element_size(dtype)
# -> 2154     typed_storage = load_tensor(
#    2155         dtype, nbytes, key, _maybe_decode_ascii(location)
#    2156     )
#    2158 return typed_storage
#
# File ~/env/lib/python3.12/site-packages/torch/serialization.py:2116, in _load.<locals>.load_tensor(dtype, nbytes, key, location)
#    2114     wrap_storage = storage
#    2115 elif torch._guards.detect_fake_mode(None) is None:
# -> 2116     wrap_storage = restore_location(storage, location)
#    2117 else:
#    2118     storage._fake_device = location
#
# File ~/env/lib/python3.12/site-packages/torch/serialization.py:734, in default_restore_location(storage, location)
#     714 """
#     715 Restores `storage` using a deserializer function registered for the `location`.
#     716
#    (...)    731        all matching ones return `None`.
#     732 """
#     733 for _, _, fn in _package_registry:
# --> 734     result = fn(storage, location)
#     735     if result is not None:
#     736         return result
#
# File ~/env/lib/python3.12/site-packages/torch/serialization.py:668, in _deserialize(backend_name, obj, location)
#     664 if location == backend_name or bool(
#     665     re.match(f"{backend_name}(:|[0-9]+)", location)
#     666 ):
#     667     device = _validate_device(location, backend_name)
# --> 668     return obj.to(device=device)
#
# File ~/env/lib/python3.12/site-packages/torch/storage.py:289, in _StorageBase.to(self, device, non_blocking)
#     287 if not isinstance(device, torch.device):
#     288     device = torch.device(device)
# --> 289 return _to(self, device, non_blocking)
#
# File ~/env/lib/python3.12/site-packages/torch/_utils.py:107, in _to(self, device, non_blocking)
#     103     raise AssertionError(
#     104         f"sparse storage is not supported for {device.type.upper()} tensors"
#     105     )
#     106 untyped_storage = torch.UntypedStorage(self.size(), device=device)
# --> 107 untyped_storage.copy_(self, non_blocking)
#     108 return untyped_storage
#
# AcceleratorError: CUDA error: device-side assert triggered
# Search for `cudaErrorAssert' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

best_acc = 0

for epoch in range(10):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = model.to(device)

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total += inputs.size(0)

    val_correct, val_total = 0, 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            val_correct += (outputs.argmax(1) == labels).sum().item()
            val_total += labels.size(0)

    val_acc = val_correct / val_total * 100
    print(f"Epoch {epoch+1} - Loss: {running_loss/total:.4f}, Val Acc: {val_acc:.2f}%")

    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), "finetuned_model/fine_tuned_model4.pth")
        print(" Nouveau meilleur modèle sauvegardé.")
# Out:
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[22], line 12
#       8     running_loss, correct, total = 0.0, 0, 0
#       9
#      10     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      11
# ---> 12     model = model.to(device)
#      13
#      14     for inputs, labels in train_loader:
#      15         inputs, labels = inputs.to(device), labels.to(device)
#
# File ~/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1384, in Module.to(self, *args, **kwargs)
#    1381         else:
#    1382             raise
# -> 1384 return self._apply(convert)
#
# File ~/env/lib/python3.12/site-packages/torch/nn/modules/module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/env/lib/python3.12/site-packages/torch/nn/modules/module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/env/lib/python3.12/site-packages/torch/nn/modules/module.py:965, in Module._apply(self, fn, recurse)
#     961 # Tensors stored in modules are graph leaves, and we don't want to
#     962 # track autograd history of `param_applied`, so we have to use
#     963 # `with torch.no_grad():`
#     964 with torch.no_grad():
# --> 965     param_applied = fn(param)
#     966 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     968 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/env/lib/python3.12/site-packages/torch/nn/modules/module.py:1370, in Module.to.<locals>.convert(t)
#    1363     if convert_to_format is not None and t.dim() in (4, 5):
#    1364         return t.to(
#    1365             device,
#    1366             dtype if t.is_floating_point() or t.is_complex() else None,
#    1367             non_blocking,
#    1368             memory_format=convert_to_format,
#    1369         )
# -> 1370     return t.to(
#    1371         device,
#    1372         dtype if t.is_floating_point() or t.is_complex() else None,
#    1373         non_blocking,
#    1374     )
#    1375 except NotImplementedError as e:
#    1376     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# AcceleratorError: CUDA error: device-side assert triggered
# Search for `cudaErrorAssert' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
